# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhumik1277/B_1277/blob/main/timeseriesmultiset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

date_range = pd.date_range(start='2023-01-01', end='2023-12-29', freq='D')
data = pd.Series(np.random.randn(len(date_range)), index=date_range)


decomposition = seasonal_decompose(data, model='additive')


plt.figure(figsize=(12, 8))


plt.subplot(2, 1, 1)
data.plot()
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')


plt.subplot(2, 1, 2)
seasonality = decomposition.seasonal
seasonality.plot()
plt.title('Seasonality')
plt.xlabel('Date')
plt.ylabel('Seasonal Component')

plt.tight_layout()
plt.show()
